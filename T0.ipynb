# %%
import pandas as pd
from pandas.io.json import json_normalize
import warnings
from TopRetweet import TopRetweet
warnings.filterwarnings("ignore")

# %% [markdown]
# Aqui sacamos todos los tweets que esta en ingles, y dejamos solamente los primeros 3 mil lineas para un mejor funcionamiento

# %%
raw_tweets = pd.read_json(r'farmers-protest-tweets-2021-03-5.json', lines=True, nrows=3000)
raw_tweets = raw_tweets[raw_tweets['lang']=='en']
# Out:
#                                                  url  \
# 0  https://twitter.com/ShashiRajbhar6/status/1376...
# 1  https://twitter.com/kaursuk06272818/status/137...
# 2  https://twitter.com/kaursuk06272818/status/137...
# 3  https://twitter.com/SukhdevSingh_/status/13767...
# 4  https://twitter.com/Davidmu66668113/status/137...
# 5  https://twitter.com/Abhimanyu_1987/status/1376...
# 6  https://twitter.com/singhwhotweets/status/1376...
# 7  https://twitter.com/J_cheeselover/status/13767...
# 8  https://twitter.com/DigitalKisanBot/status/137...
# 9  https://twitter.com/rajriarhughes/status/13767...
#
#                        date  \
# 0 2021-03-30 03:33:46+00:00
# 1 2021-03-30 03:33:23+00:00
# 2 2021-03-30 03:31:00+00:00
# 3 2021-03-30 03:30:45+00:00
# 4 2021-03-30 03:30:30+00:00
# 5 2021-03-30 03:29:56+00:00
# 6 2021-03-30 03:28:50+00:00
# 7 2021-03-30 03:28:49+00:00
# 8 2021-03-30 03:28:09+00:00
# 9 2021-03-30 03:28:04+00:00
#
#                                              content  \
# 0                       Support 👇\n\n#FarmersProtest
# 1  Supporting farmers means supporting our countr...
# 2  Support farmers if you are related to food #St...
# 3  #StopHateAgainstFarmers support #FarmersProtes...
# 4  You hate farmers I hate you, \nif you love the...
# 5  They can't be farmers. Looks like Gundas are h...
# 6  Lets not forget that our Farmers are STILL out...
# 7  @Troll48611422 @Doabapunjab1 @Terminator00096 ...
# 8  Neutrality helps the oppressor, never the vict...
# 9  Why You Should Visit the F.A.R.M.E.R. at Tikri...
#
#                                      renderedContent                   id  \
# 0                       Support 👇\n\n#FarmersProtest  1376739399593910273
# 1  Supporting farmers means supporting our countr...  1376739306287427584
# 2  Support farmers if you are related to food #St...  1376738704128020488
# 3  #StopHateAgainstFarmers support #FarmersProtes...  1376738640542400518
# 4  You hate farmers I hate you, \nif you love the...  1376738579171344386
# 5  They can't be farmers. Looks like Gundas are h...  1376738436099399686
# 6  Lets not forget that our Farmers are STILL out...  1376738161800306690
# 7  @Troll48611422 @Doabapunjab1 @Terminator00096 ...  1376738155110395904
# 8  Neutrality helps the oppressor, never the vict...  1376737987791323142
# 9  Why You Should Visit the F.A.R.M.E.R. at Tikri...  1376737966530338819
#
#                                                 user  \
# 0  {'username': 'ShashiRajbhar6', 'displayname': ...
# 1  {'username': 'kaursuk06272818', 'displayname':...
# 2  {'username': 'kaursuk06272818', 'displayname':...
# 3  {'username': 'SukhdevSingh_', 'displayname': '...
# 4  {'username': 'Davidmu66668113', 'displayname':...
# 5  {'username': 'Abhimanyu_1987', 'displayname': ...
# 6  {'username': 'singhwhotweets', 'displayname': ...
# 7  {'username': 'J_cheeselover', 'displayname': '...
# 8  {'username': 'DigitalKisanBot', 'displayname':...
# 9  {'username': 'rajriarhughes', 'displayname': '...
#
#                                             outlinks  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5  [https://twitter.com/IndiaToday/status/1376730...
# 6                                                 []
# 7                                                 []
# 8                                                 []
# 9  [https://thewire.in/rights/tikri-border-farmer...
#
#                  tcooutlinks  replyCount  retweetCount  ...  quoteCount  \
# 0                         []           0             0  ...           0
# 1                         []           0             0  ...           0
# 2                         []           0             0  ...           0
# 3                         []           0             1  ...           0
# 4                         []           0             0  ...           0
# 5  [https://t.co/6kFJpX2mx0]           0             0  ...           0
# 6                         []           0             2  ...           0
# 7                         []           1             0  ...           0
# 8                         []           0             0  ...           0
# 9  [https://t.co/gS8glayNfe]           0             0  ...           0
#
#         conversationId  lang  \
# 0  1376739399593910273    en
# 1  1376739306287427584    en
# 2  1376738704128020488    en
# 3  1376738640542400518    en
# 4  1376738579171344386    en
# 5  1376738436099399686    en
# 6  1376738161800306690    en
# 7  1375872568129855491    en
# 8  1376737987791323142    en
# 9  1376737966530338819    en
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/android" ...
# 5  <a href="http://twitter.com/download/android" ...
# 6  <a href="http://twitter.com/download/android" ...
# 7  <a href="http://twitter.com/download/iphone" r...
# 8
# 9  <a href="https://mobile.twitter.com" rel="nofo...
#
#                              sourceUrl          sourceLabel  \
# 0  http://twitter.com/download/android  Twitter for Android
# 1  http://twitter.com/download/android  Twitter for Android
# 2  http://twitter.com/download/android  Twitter for Android
# 3  http://twitter.com/download/android  Twitter for Android
# 4  http://twitter.com/download/android  Twitter for Android
# 5  http://twitter.com/download/android  Twitter for Android
# 6  http://twitter.com/download/android  Twitter for Android
# 7   http://twitter.com/download/iphone   Twitter for iPhone
# 8                                 None                 None
# 9           https://mobile.twitter.com      Twitter Web App
#
#                                                media retweetedTweet  \
# 0                                               None            NaN
# 1  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 2  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 3                                               None            NaN
# 4                                               None            NaN
# 5                                               None            NaN
# 6  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 7  [{'thumbnailUrl': 'https://pbs.twimg.com/tweet...            NaN
# 8                                               None            NaN
# 9                                               None            NaN
#
#                                          quotedTweet  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5  {'url': 'https://twitter.com/IndiaToday/status...
# 6                                               None
# 7                                               None
# 8                                               None
# 9                                               None
#
#                                       mentionedUsers
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6                                               None
# 7  [{'username': 'Troll48611422', 'displayname': ...
# 8                                               None
# 9  [{'username': 'thewire_in', 'displayname': 'Th...
#
# [10 rows x 21 columns]

# %% [markdown]
# Aqui definimos el top 10 retweeted

# %%
TopRetweet(raw_tweets).head(10)
# Out:
#                                                     url  \
# 1304  https://twitter.com/saahilmenghani/status/1376...
# 2955  https://twitter.com/amaanbali/status/137622784...
# 1374  https://twitter.com/Devinder_Sharma/status/137...
# 372   https://twitter.com/NavJammu/status/1376714448...
# 2716  https://twitter.com/Khalsa_Aid/status/13763028...
# 2701  https://twitter.com/amanmangat08/status/137631...
# 464   https://twitter.com/NavJammu/status/1376712476...
# 2570  https://twitter.com/Navneet_Tweets_/status/137...
# 526   https://twitter.com/NavJammu/status/1376709851...
# 2523  https://twitter.com/AntiITcellTask1/status/137...
#
#                           date  \
# 1304 2021-03-29 09:36:24+00:00
# 2955 2021-03-28 17:41:01+00:00
# 1374 2021-03-29 08:25:29+00:00
# 372  2021-03-30 01:54:37+00:00
# 2716 2021-03-28 22:39:03+00:00
# 2701 2021-03-28 23:33:08+00:00
# 464  2021-03-30 01:46:47+00:00
# 2570 2021-03-29 01:38:35+00:00
# 526  2021-03-30 01:36:21+00:00
# 2523 2021-03-29 01:43:51+00:00
#
#                                                 content  \
# 1304  Ouch!  #Colourful  Happy  Holi  at  Singhu  Bo...
# 2955  Rakesh Tikait burnt copies of the farm laws at...
# 1374  Public support is growing for #FarmersProtest....
# 372   Did you know farmers in India continue to live...
# 2716  So many people from so many countries are now ...
# 2701  Brampton people are nailing it from the day on...
# 464   Let’s stand with our elders &amp; show the wor...
# 2570  Colors of #FarmersProtest \nLove\nSacrifice \n...
# 526   Greetings everyone! 🙏🏼\n\nFarmers have been pe...
# 2523  If you love color of delicious food,\nLet’s ce...
#
#                                         renderedContent                   id  \
# 1304  Ouch!  #Colourful  Happy  Holi  at  Singhu  Bo...  1376468273013813250
# 2955  Rakesh Tikait burnt copies of the farm laws at...  1376227842049011714
# 1374  Public support is growing for #FarmersProtest....  1376450427017826308
# 372   Did you know farmers in India continue to live...  1376714448409223179
# 2716  So many people from so many countries are now ...  1376302844224102400
# 2701  Brampton people are nailing it from the day on...  1376316455650697216
# 464   Let’s stand with our elders &amp; show the wor...  1376712476528537602
# 2570  Colors of #FarmersProtest \nLove\nSacrifice \n...  1376348025673543683
# 526   Greetings everyone! 🙏🏼\n\nFarmers have been pe...  1376709851531804673
# 2523  If you love color of delicious food,\nLet’s ce...  1376349352306700288
#
#                                                    user outlinks tcooutlinks  \
# 1304  {'username': 'saahilmenghani', 'displayname': ...       []          []
# 2955  {'username': 'amaanbali', 'displayname': 'Amaa...       []          []
# 1374  {'username': 'Devinder_Sharma', 'displayname':...       []          []
# 372   {'username': 'NavJammu', 'displayname': 'Navne...       []          []
# 2716  {'username': 'Khalsa_Aid', 'displayname': 'Kha...       []          []
# 2701  {'username': 'amanmangat08', 'displayname': 'D...       []          []
# 464   {'username': 'NavJammu', 'displayname': 'Navne...       []          []
# 2570  {'username': 'Navneet_Tweets_', 'displayname':...       []          []
# 526   {'username': 'NavJammu', 'displayname': 'Navne...       []          []
# 2523  {'username': 'AntiITcellTask1', 'displayname':...       []          []
#
#       replyCount  retweetCount  ...  quoteCount       conversationId  lang  \
# 1304          27           237  ...           7  1376468273013813250    en
# 2955          28           237  ...          20  1376227842049011714    en
# 1374          10           231  ...          11  1376450427017826308    en
# 372            0           206  ...          13  1376714448409223179    en
# 2716          11           171  ...          13  1376302844224102400    en
# 2701          27           168  ...          12  1376316455650697216    en
# 464            0           160  ...          13  1376712476528537602    en
# 2570           7           157  ...           9  1376348025673543683    en
# 526            0           153  ...          17  1376709851531804673    en
# 2523           8           144  ...           6  1376349352306700288    en
#
#                                                  source  \
# 1304  <a href="https://studio.twitter.com" rel="nofo...
# 2955  <a href="http://twitter.com/download/iphone" r...
# 1374  <a href="http://twitter.com/download/android" ...
# 372   <a href="http://twitter.com/download/iphone" r...
# 2716  <a href="http://twitter.com/download/iphone" r...
# 2701  <a href="http://twitter.com/download/iphone" r...
# 464   <a href="http://twitter.com/download/iphone" r...
# 2570  <a href="http://twitter.com/download/iphone" r...
# 526   <a href="http://twitter.com/download/iphone" r...
# 2523  <a href="http://twitter.com/download/iphone" r...
#
#                                 sourceUrl           sourceLabel  \
# 1304           https://studio.twitter.com  Twitter Media Studio
# 2955   http://twitter.com/download/iphone    Twitter for iPhone
# 1374  http://twitter.com/download/android   Twitter for Android
# 372    http://twitter.com/download/iphone    Twitter for iPhone
# 2716   http://twitter.com/download/iphone    Twitter for iPhone
# 2701   http://twitter.com/download/iphone    Twitter for iPhone
# 464    http://twitter.com/download/iphone    Twitter for iPhone
# 2570   http://twitter.com/download/iphone    Twitter for iPhone
# 526    http://twitter.com/download/iphone    Twitter for iPhone
# 2523   http://twitter.com/download/iphone    Twitter for iPhone
#
#                                                   media retweetedTweet  \
# 1304  [{'thumbnailUrl': 'https://pbs.twimg.com/ampli...            NaN
# 2955  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 1374  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 372   [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 2716  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 2701  [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...            NaN
# 464   [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 2570  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 526   [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 2523  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
#
#       quotedTweet mentionedUsers
# 1304         None           None
# 2955         None           None
# 1374         None           None
# 372          None           None
# 2716         None           None
# 2701         None           None
# 464          None           None
# 2570         None           None
# 526          None           None
# 2523         None           None
#
# [10 rows x 21 columns]
